# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
sales_df = pd.read_csv("./dataset/train.csv")
sales_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
from ydata_profiling import ProfileReport
# Out:
# C:\Users\simra\AppData\Local\Temp\ipykernel_26120\44057814.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
# %pip install -U fg-data-profiling
# Out:
# Collecting fg-data-profiling
#   Downloading fg_data_profiling-4.19.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\simra\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (4.6.0)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\simra\anaconda3\lib\site-packages (from fg-data-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\simra\anaconda3\lib\site-packages (from imagehash==4.3.2->fg-data-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\simra\anaconda3\lib\site-packages (from imagehash==4.3.2->fg-data-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\simra\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->fg-data-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\simra\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\simra\anaconda3\lib\site-packages (from numba<0.63,>=0.60->fg-data-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\simra\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\simra\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\simra\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->fg-data-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\simra\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\simra\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\simra\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\simra\anaconda3\lib\site-packages (from pydantic<3,>=2->fg-data-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\simra\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\simra\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\simra\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\simra\anaconda3\lib\site-packages (from requests<3,>=2.32.0->fg-data-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\simra\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->fg-data-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\simra\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->fg-data-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\simra\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\simra\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (3.5)
# Requirement already satisfied: puremagic in c:\users\simra\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\simra\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->fg-data-profiling) (1.17.0)
# Downloading fg_data_profiling-4.19.1-py2.py3-none-any.whl (400 kB)
# Installing collected packages: fg-data-profiling
# Successfully installed fg-data-profiling-4.19.1
# Note: you may need to restart the kernel to use updated packages.

# %%
profile = ProfileReport(df, title="Black Friday Sales Report")
profile.to_file("report.html")
