# %% [markdown]
# #### Package Installation

# %%
# !pip install -r requirements.txt

# %% [markdown]
# #### Import Common libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Initial Data Analysis

# %%
sales_df = pd.read_csv("./dataset/train.csv")
sales_df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
sales_df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
sales_df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
sales_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Univariate Analysis

# %%
sales_df['Age'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Age'>

# %%
sales_df['City_Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City_Category'>

# %%
sales_df['Gender'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.boxplot(sales_df['Occupation'].value_counts())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fa01754e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fa01755090>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fa01754cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fa01755310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fa01755450>],
#  'means': []}

# %%
sales_df['Marital_Status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sales_df['Stay_In_Current_City_Years'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %% [markdown]
# #### Bi-Variate Analysis / Multi Variate Analysis

# %%
sns.barplot(y="Purchase", x="Gender", data=sales_df)
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
sns.boxplot(y="Purchase", x="Age", data=sales_df)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
sns.lineplot(y="Purchase", x="Occupation", data=sales_df)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.displot(y="Purchase", x="Stay_In_Current_City_Years", data=sales_df)

# %%
sns.barplot(y="Purchase", x="City_Category", data=sales_df)
# Out:
# <Axes: xlabel='City_Category', ylabel='Purchase'>

# %%
sns.boxplot(x="Gender", y="Purchase", data=sales_df, hue="Marital_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
sns.boxplot(x="Age", y="Purchase", data=sales_df, hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
sns.lineplot(x="Occupation", y="Purchase", data=sales_df, hue="City_Category")
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot(x="Stay_In_Current_City_Years", y="Purchase", data=sales_df, hue="City_Category")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='Purchase'>

# %%
sns.scatterplot(x="Product_Category_2", y="Product_Category_1", data=sales_df, hue="Product_Category_3")
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Product_Category_1'>

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# ### Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(sales_df.drop("Purchase", axis=1), sales_df["Purchase"], test_size=0.2, random_state=42)

X_train.shape, X_test.shape
# Out:
# ((440054, 11), (110014, 11))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 440054 entries, 178247 to 121958
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     440054 non-null  int64
#  1   Product_ID                  440054 non-null  object
#  2   Gender                      440054 non-null  object
#  3   Age                         440054 non-null  object
#  4   Occupation                  440054 non-null  int64
#  5   City_Category               440054 non-null  object
#  6   Stay_In_Current_City_Years  440054 non-null  object
#  7   Marital_Status              440054 non-null  int64
#  8   Product_Category_1          440054 non-null  int64
#  9   Product_Category_2          301010 non-null  float64
#  10  Product_Category_3          133226 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 40.3+ MB

# %% [markdown]
# ### Machine Learning Pipeline Implementation

# %% [markdown]
# Useful Columns: Gender, Age, Occupation, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase
# Non-useful: User_ID, Product_ID

# %% [markdown]
# #### 1. Drop User_ID and Product_ID Column

# %%
from sklearn.preprocessing import FunctionTransformer

trf1 = FunctionTransformer(
    lambda x: x.drop(columns=["User_ID", "Product_ID"])
)

X_train_temp = trf1.fit_transform(X_train)
X_train_temp.sample(1)
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 446216      F  51-55          20             B                          1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 446216               1                   2                 4.0
#
#         Product_Category_3
# 446216                 9.0

# %% [markdown]
# #### 2. Transform Columns
#
# ##### - Replace 4+ with 4 in Stay_In_Current_City_Years
# ##### - Make a new feature "Product_Hierarchy" showing the hierarchy between the product categories

# %%
X_train["Stay_In_Current_City_Years"].unique()
# Out:
# array(['3', '4+', '1', '2', '0'], dtype=object)

# %%
# X_train["Stay_In_Current_City_Years"] = X_train["Stay_In_Current_City_Years"].replace("4+", 4)
# X_test["Stay_In_Current_City_Years"] = X_test["Stay_In_Current_City_Years"].replace("4+", 4)
# X_train["Stay_In_Current_City_Years"].unique()

trf2 = FunctionTransformer(
    lambda x: x.assign(Stay_In_Current_City_Years=
        x["Stay_In_Current_City_Years"].replace("4+", 4),
                      Product_Hierarchy=
        x["Product_Category_1"].astype(str) + "_" +
        x["Product_Category_2"].fillna(0).astype(int).astype(str) + "_" +
        x["Product_Category_3"].fillna(0).astype(int).astype(str)
                      )
)

X_train_temp = trf2.fit_transform(X_train)
X_train_temp.sample(1)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 102615  1003834  P00057242      M  18-25           2             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 102615                          2               0                   5
#
#         Product_Category_2  Product_Category_3 Product_Hierarchy
# 102615                 NaN                 NaN             5_0_0

# %% [markdown]
# #### 3. Encoding
#
# ##### - One-Hot Encoding on Gender and City_Category
# ##### - Ordinal Encoding on Age column
# ##### - SimpleImputer for handling Missing Values in Product_Category_2 and Product_Category_3 columns to replace NAN with 0

# %%
X_train["Age"].unique()
# Out:
# array(['51-55', '18-25', '26-35', '36-45', '46-50', '55+', '0-17'],
#       dtype=object)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer

# Ordinal Encoding and One Hot Encoding
trf3 = ColumnTransformer(transformers=[
    ('trf_4_1', OrdinalEncoder(categories = [['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+']]), ['Age']),
    ('trf_4_3', SimpleImputer(strategy="constant", fill_value=0), ['Product_Category_2', 'Product_Category_3']),
    ('trf_4_2', OneHotEncoder(drop="first", sparse_output=False, handle_unknown="ignore"), ['Gender', 'City_Category', 'Product_Category_1',
                                                                   'Product_Category_2', 'Product_Category_3', 'Product_Hierarchy'])
], remainder="passthrough")

trf3.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('trf_4_1',
#                                  OrdinalEncoder(categories=[['0-17', '18-25',
#                                                              '26-35', '36-45',
#                                                              '46-50', '51-55',
#                                                              '55+']]),
#                                  ['Age']),
#                                 ('trf_4_3',
#                                  SimpleImputer(fill_value=0,
#                                                strategy='constant'),
#                                  ['Product_Category_2', 'Product_Category_3']),
#                                 ('trf_4_2',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore',
#                                                sparse_output=False),
# ...

# %% [markdown]
# #### 4. Feature Scaling
#
# ##### - StandardScaler on every feature

# %%
from sklearn.preprocessing import StandardScaler

trf4 = StandardScaler()

# %% [markdown]
# #### 5. Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

trf5 = LinearRegression()

# %% [markdown]
# #### 6. Pipeline Implementation and Model Fit

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ("trf1", trf1),
    ("trf2", trf2),
    ("trf3", trf3),
    ("trf4", trf4),
    ("trf5", trf5)
])

# %%
# train the pipeline

pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  FunctionTransformer(func=<function <lambda> at 0x000001FA08BB5E40>)),
#                 ('trf2',
#                  FunctionTransformer(func=<function <lambda> at 0x000001FA01F28180>)),
#                 ('trf3',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf_4_1',
#                                                   OrdinalEncoder(categories=[['0-17',
#                                                                               '18-25',
#                                                                               '26-35',
#                                                                               '36-45',
#                                                                               '46-50',
#                                                                               '51-55',
# ...

# %% [markdown]
# ### Testing & Evaluation:
#
# #### - Applied test and evaluate based on different matrices

# %%
Y_pred = pipe.predict(X_test)
# Out:
# C:\Users\simra\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE:", mean_absolute_error(Y_test, Y_pred))
print("RMSE:", np.sqrt(mean_squared_error(Y_test, Y_pred)))
print("R2:", r2_score(Y_test, Y_pred))
# Out:
# MAE: 2208.914490137707
# RMSE: 2946.0918878901466
# R2: 0.6545651813798214

# %% [markdown]
# #### - Comparison between test and train prediction

# %%
train_pred = pipe.predict(X_train)

print("Train R2:", r2_score(Y_train, train_pred))
print("Test R2:", r2_score(Y_test, Y_pred))
# Out:
# Train R2: 0.6619149740240557
# Test R2: 0.6545651813798214

# %% [markdown]
# #### - Linear Regression Plotting

# %%
plt.scatter(Y_test, Y_pred, s=5)

plt.plot(
    [Y_test.min(), Y_test.max()],
    [Y_test.min(), Y_test.max()]
)

plt.xlabel('Actual Purchase')
plt.ylabel('Predicted Purchase')
plt.show()

# %% [markdown]
# ### Prediction
#
# #### - Prediction of Purchase for New Customers

# %%
new_customer_df = pd.read_csv("./dataset/test.csv")

new_customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
predicted_purchases = pipe.predict(new_customer_df)

# %%
new_customer_df["Purchase"] = predicted_purchases.round().astype(int)

new_customer_df.sample(5)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 139626  1004858  P00355642      M  26-35           1             C
# 100891  1005434  P00114942      F  26-35           7             A
# 188071  1001804  P00111842      M  26-35           7             C
# 146791  1003864  P00100942      M  51-55          20             C
# 127100  1003887  P00007942      M  18-25           4             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 139626                          2               0                  16
# 100891                          1               1                   1
# 188071                         4+               1                   8
# 146791                          0               1                   5
# 127100                          1               0                   8
#
#         Product_Category_2  Product_Category_3  Purchase
# 139626                 NaN                 NaN     15064
# ...

# %% [markdown]
# #### - Exported predicted purchase in new file.

# %%
new_customer_df.to_csv("./output/predicted_purchase.csv", index=False)
